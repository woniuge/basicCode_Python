# %% [markdown]
# 1. Basic usage

# %% [markdown]
#     1.1 Automatic cross-validation

# %%
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import cross_validate

# Load the movielens-100k dataset (download it if needed)
data = Dataset.load_builtin('ml-100k')

# %%
# We'll use the famous SVD algorithm
algo = SVD()

# %%
# Run 5-fold cross-validation and print results
cross_validate(algo,data,measures=['RMSE','MAE'],cv=5,verbose=True)
# Out:
# Evaluating RMSE, MAE of algorithm SVD on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9427  0.9318  0.9348  0.9333  0.9389  0.9363  0.0040
# MAE (testset)     0.7416  0.7307  0.7380  0.7356  0.7401  0.7372  0.0038
# Fit time          4.56    4.42    4.43    4.41    4.46    4.46    0.05
# Test time         0.84    0.14    0.12    0.14    0.11    0.27    0.29
# {'test_rmse': array([0.94266092, 0.93180989, 0.93478787, 0.93326425, 0.93892981]),
#  'test_mae': array([0.74163883, 0.730727  , 0.73798741, 0.73560876, 0.74014399]),
#  'fit_time': (4.555803537368774,
#   4.423142910003662,
#   4.431175470352173,
#   4.414164781570435,
#   4.4560816287994385),
#  'test_time': (0.842231273651123,
#   0.13862919807434082,
#   0.11668729782104492,
#   0.13962697982788086,
#   0.11170220375061035)}

# %% [markdown]
#     1.2 Train-test split and the fit() method

# %%
from surprise import SVD
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import train_test_split

# Load the movielens-100k dataset (download it if needed)
data = Dataset.load_builtin('ml-100k')

# %%
# sample random trainset and testset
# test set is made of 25% of the ratings
trainset,testset = train_test_split(data,test_size=.25)

# %%
# We'll use the famous SVD algorithm
algo = SVD()

# %%
# Train the algorithm on the trainset, and predict ratings for the testset
algo.fit(trainset)
predictions = algo.test(testset)

# %%
predictions
# Out:
# [Prediction(uid='1', iid='3', r_ui=4.0, est=3.209984476408625, details={'was_impossible': False}),
#  Prediction(uid='1', iid='13', r_ui=5.0, est=3.406438476287819, details={'was_impossible': False}),
#  Prediction(uid='1', iid='15', r_ui=5.0, est=3.679458750627329, details={'was_impossible': False}),
#  Prediction(uid='1', iid='18', r_ui=4.0, est=3.341154880376516, details={'was_impossible': False}),
#  Prediction(uid='1', iid='19', r_ui=5.0, est=3.805277301137605, details={'was_impossible': False}),
#  Prediction(uid='1', iid='28', r_ui=4.0, est=3.8063264158617574, details={'was_impossible': False}),
#  Prediction(uid='1', iid='29', r_ui=1.0, est=3.006277098019457, details={'was_impossible': False}),
#  Prediction(uid='1', iid='52', r_ui=4.0, est=3.7595961289572153, details={'was_impossible': False}),
#  Prediction(uid='1', iid='59', r_ui=5.0, est=3.9375908267144433, details={'was_impossible': False}),
#  Prediction(uid='1', iid='83', r_ui=3.0, est=3.8845647396301564, details={'was_impossible': False}),
#  Prediction(uid='1', iid='88', r_ui=4.0, est=3.5019552072600644, details={'was_impossible': False}),
#  Prediction(uid='1', iid='94', r_ui=2.0, est=3.237038877344838, details={'was_impossible': False}),
#  Prediction(uid='1', iid='111', r_ui=5.0, est=3.500413904988477, details={'was_impossible': False}),
#  Prediction(uid='1', iid='122', r_ui=3.0, est=2.727916085462342, details={'was_impossible': False}),
#  Prediction(uid='1', iid='126', r_ui=2.0, est=3.701444109490975, details={'was_impossible': False}),
#  Prediction(uid='1', iid='152', r_ui=5.0, est=3.582911111401715, details={'was_impossible': False}),
#  Prediction(uid='1', iid='172', r_ui=5.0, est=3.9998396894268766, details={'was_impossible': False}),
#  Prediction(uid='1', iid='204', r_ui=5.0, est=3.7224587441637214, details={'was_impossible': False}),
#  Prediction(uid='1', iid='207', r_ui=5.0, est=3.8043393234066043, details={'was_impossible': False}),
#  Prediction(uid='1', iid='231', r_ui=1.0, est=2.9444159613315484, details={'was_impossible': False}),
#  Prediction(uid='1', iid='244', r_ui=2.0, est=3.2667734074362933, details={'was_impossible': False}),
#  Prediction(uid='2', iid='275', r_ui=5.0, est=3.8532877780020702, details={'was_impossible': False}),
#  Prediction(uid='2', iid='286', r_ui=4.0, est=3.6286610341995016, details={'was_impossible': False}),
#  Prediction(uid='2', iid='296', r_ui=3.0, est=3.561272149168628, details={'was_impossible': False}),
#  Prediction(uid='2', iid='302', r_ui=5.0, est=4.03395820542082, details={'was_impossible': False}),
#  Prediction(uid='3', iid='340', r_ui=5.0, est=3.170794235387515, details={'was_impossible': False}),
#  Prediction(uid='3', iid='346', r_ui=5.0, est=3.252488586894771, details={'was_impossible': False}),
#  Prediction(uid='3', iid='353', r_ui=1.0, est=2.708080764392754, details={'was_impossible': False}),
#  Prediction(uid='4', iid='301', r_ui=5.0, est=3.761055986039073, details={'was_impossible': False}),
#  Prediction(uid='4', iid='360', r_ui=5.0, est=3.8274750135462288, details={'was_impossible': False}),
#  Prediction(uid='5', iid='105', r_ui=3.0, est=2.3555362954278536, details={'was_impossible': False}),
#  Prediction(uid='5', iid='174', r_ui=5.0, est=3.582179019277119, details={'was_impossible': False}),
#  Prediction(uid='5', iid='200', r_ui=2.0, est=3.230990548860757, details={'was_impossible': False}),
#  Prediction(uid='5', iid='210', r_ui=3.0, est=3.3203586596685124, details={'was_impossible': False}),
#  Prediction(uid='5', iid='233', r_ui=4.0, est=2.8238561049079403, details={'was_impossible': False}),
#  Prediction(uid='5', iid='368', r_ui=1.0, est=2.0763875302690002, details={'was_impossible': False}),
#  Prediction(uid='5', iid='373', r_ui=3.0, est=2.694453291456708, details={'was_impossible': False}),
#  Prediction(uid='5', iid='375', r_ui=3.0, est=2.215474665119577, details={'was_impossible': False}),
#  Prediction(uid='5', iid='380', r_ui=3.0, est=2.9472286250990174, details={'was_impossible': False}),
#  Prediction(uid='5', iid='383', r_ui=3.0, est=2.122682828299888, details={'was_impossible': False}),
#  Prediction(uid='5', iid='419', r_ui=3.0, est=3.205233599800588, details={'was_impossible': False}),
#  Prediction(uid='5', iid='448', r_ui=2.0, est=3.0268735254032166, details={'was_impossible': False}),
#  Prediction(uid='6', iid='8', r_ui=4.0, est=3.827887327251582, details={'was_impossible': False}),
#  Prediction(uid='6', iid='111', r_ui=2.0, est=3.452495661817428, details={'was_impossible': False}),
#  Prediction(uid='6', iid='182', r_ui=4.0, est=3.780338841309633, details={'was_impossible': False}),
#  Prediction(uid='6', iid='202', r_ui=3.0, est=3.6747107487780326, details={'was_impossible': False}),
#  Prediction(uid='6', iid='216', r_ui=5.0, est=3.7723513563328512, details={'was_impossible': False}),
#  Prediction(uid='6', iid='237', r_ui=2.0, est=3.6132334611161796, details={'was_impossible': False}),
#  Prediction(uid='6', iid='285', r_ui=3.0, est=4.027655027875313, details={'was_impossible': False}),
#  Prediction(uid='6', iid='306', r_ui=4.0, est=3.782087480576848, details={'was_impossible': False}),
#  Prediction(uid='6', iid='490', r_ui=5.0, est=3.783117252362176, details={'was_impossible': False}),
#  Prediction(uid='6', iid='496', r_ui=4.0, est=3.889617127018302, details={'was_impossible': False}),
#  Prediction(uid='6', iid='533', r_ui=4.0, est=3.5777152317353482, details={'was_impossible': False}),
#  Prediction(uid='6', iid='537', r_ui=4.0, est=3.5415306273354195, details={'was_impossible': False}),
#  Prediction(uid='6', iid='539', r_ui=2.0, est=2.8224969960572794, details={'was_impossible': False}),
#  Prediction(uid='7', iid='12', r_ui=5.0, est=4.402429613014188, details={'was_impossible': False}),
#  Prediction(uid='7', iid='50', r_ui=5.0, est=4.3927844692611595, details={'was_impossible': False}),
#  Prediction(uid='7', iid='86', r_ui=4.0, est=4.087085881477165, details={'was_impossible': False}),
#  Prediction(uid='7', iid='144', r_ui=5.0, est=4.080296815214097, details={'was_impossible': False}),
#  Prediction(uid='7', iid='152', r_ui=4.0, est=3.8392839566460695, details={'was_impossible': False}),
#  Prediction(uid='7', iid='164', r_ui=5.0, est=3.863728960035657, details={'was_impossible': False}),
#  Prediction(uid='7', iid='173', r_ui=5.0, est=4.278770033032672, details={'was_impossible': False}),
#  Prediction(uid='7', iid='197', r_ui=4.0, est=4.161191408998389, details={'was_impossible': False}),
#  Prediction(uid='7', iid='198', r_ui=3.0, est=4.115417663400746, details={'was_impossible': False}),
#  Prediction(uid='7', iid='211', r_ui=5.0, est=4.038375606110172, details={'was_impossible': False}),
#  Prediction(uid='7', iid='309', r_ui=3.0, est=3.4256929439216117, details={'was_impossible': False}),
#  Prediction(uid='7', iid='317', r_ui=4.0, est=4.067690628986218, details={'was_impossible': False}),
#  Prediction(uid='7', iid='357', r_ui=5.0, est=4.321913690848013, details={'was_impossible': False}),
#  Prediction(uid='7', iid='367', r_ui=5.0, est=3.7539079938473896, details={'was_impossible': False}),
#  Prediction(uid='7', iid='421', r_ui=3.0, est=3.811013682073217, details={'was_impossible': False}),
#  Prediction(uid='7', iid='441', r_ui=2.0, est=3.12390638297309, details={'was_impossible': False}),
#  Prediction(uid='7', iid='509', r_ui=5.0, est=4.008776267085575, details={'was_impossible': False}),
#  Prediction(uid='7', iid='521', r_ui=5.0, est=3.95560943938409, details={'was_impossible': False}),
#  Prediction(uid='7', iid='561', r_ui=4.0, est=3.519308587317616, details={'was_impossible': False}),
#  Prediction(uid='7', iid='569', r_ui=4.0, est=3.2899463020229303, details={'was_impossible': False}),
#  Prediction(uid='7', iid='598', r_ui=3.0, est=3.683005874634614, details={'was_impossible': False}),
#  Prediction(uid='7', iid='607', r_ui=3.0, est=4.157261669924149, details={'was_impossible': False}),
#  Prediction(uid='7', iid='639', r_ui=5.0, est=3.9033906205456437, details={'was_impossible': False}),
#  Prediction(uid='8', iid='243', r_ui=2.0, est=2.9342880501021673, details={'was_impossible': False}),
#  Prediction(uid='8', iid='260', r_ui=3.0, est=2.981238112850647, details={'was_impossible': False}),
#  Prediction(uid='8', iid='358', r_ui=2.0, est=3.080012329781472, details={'was_impossible': False}),
#  Prediction(uid='8', iid='566', r_ui=3.0, est=3.7264989770680756, details={'was_impossible': False}),
#  Prediction(uid='9', iid='7', r_ui=4.0, est=4.037127568928534, details={'was_impossible': False}),
#  Prediction(uid='9', iid='385', r_ui=5.0, est=3.8841667219737155, details={'was_impossible': False}),
#  Prediction(uid='10', iid='9', r_ui=4.0, est=4.074580353466502, details={'was_impossible': False}),
#  Prediction(uid='10', iid='12', r_ui=5.0, est=4.469159931555849, details={'was_impossible': False}),
#  Prediction(uid='10', iid='23', r_ui=5.0, est=4.268881764713569, details={'was_impossible': False}),
#  Prediction(uid='10', iid='40', r_ui=4.0, est=3.4321494597563675, details={'was_impossible': False}),
#  Prediction(uid='10', iid='85', r_ui=4.0, est=3.545617577015345, details={'was_impossible': False}),
#  Prediction(uid='10', iid='93', r_ui=4.0, est=4.037485784856211, details={'was_impossible': False}),
#  Prediction(uid='10', iid='153', r_ui=4.0, est=4.024660307877936, details={'was_impossible': False}),
#  Prediction(uid='10', iid='179', r_ui=5.0, est=4.119866570814844, details={'was_impossible': False}),
#  Prediction(uid='10', iid='198', r_ui=3.0, est=4.179810111607902, details={'was_impossible': False}),
#  Prediction(uid='10', iid='286', r_ui=4.0, est=3.9197699448037, details={'was_impossible': False}),
#  Prediction(uid='10', iid='479', r_ui=5.0, est=4.333550870369631, details={'was_impossible': False}),
#  Prediction(uid='10', iid='484', r_ui=5.0, est=4.31885230308731, details={'was_impossible': False}),
#  Prediction(uid='10', iid='525', r_ui=5.0, est=4.142670379547603, details={'was_impossible': False}),
#  Prediction(uid='10', iid='604', r_ui=4.0, est=4.231460427981651, details={'was_impossible': False}),
#  Prediction(uid='10', iid='610', r_ui=4.0, est=3.9330433058979546, details={'was_impossible': False}),
#  Prediction(uid='10', iid='686', r_ui=4.0, est=4.010020821776375, details={'was_impossible': False}),
#  Prediction(uid='10', iid='700', r_ui=4.0, est=3.470840433191998, details={'was_impossible': False}),
#  Prediction(uid='10', iid='707', r_ui=5.0, est=4.054833855179967, details={'was_impossible': False}),
#  Prediction(uid='11', iid='11', r_ui=2.0, est=3.7677258653631354, details={'was_impossible': False}),
#  Prediction(uid='11', iid='107', r_ui=4.0, est=3.4906637681145223, details={'was_impossible': False}),
#  Prediction(uid='11', iid='173', r_ui=5.0, est=4.00408654645185, details={'was_impossible': False}),
#  Prediction(uid='11', iid='213', r_ui=4.0, est=3.8362213315970974, details={'was_impossible': False}),
#  Prediction(uid='11', iid='229', r_ui=4.0, est=3.236518733326802, details={'was_impossible': False}),
#  Prediction(uid='11', iid='239', r_ui=4.0, est=3.5222052022774117, details={'was_impossible': False}),
#  Prediction(uid='11', iid='324', r_ui=1.0, est=3.267976426601467, details={'was_impossible': False}),
#  Prediction(uid='11', iid='356', r_ui=4.0, est=3.425902357290319, details={'was_impossible': False}),
#  Prediction(uid='11', iid='365', r_ui=3.0, est=3.3749772868148447, details={'was_impossible': False}),
#  Prediction(uid='11', iid='382', r_ui=3.0, est=3.5293374061649825, details={'was_impossible': False}),
#  Prediction(uid='11', iid='393', r_ui=4.0, est=3.3586911822264836, details={'was_impossible': False}),
#  Prediction(uid='11', iid='399', r_ui=3.0, est=3.41410696495818, details={'was_impossible': False}),
#  Prediction(uid='11', iid='431', r_ui=2.0, est=3.5306577856431245, details={'was_impossible': False}),
#  Prediction(uid='11', iid='451', r_ui=2.0, est=3.3599008889466715, details={'was_impossible': False}),
#  Prediction(uid='11', iid='747', r_ui=3.0, est=3.436655842417452, details={'was_impossible': False}),
#  Prediction(uid='12', iid='69', r_ui=5.0, est=4.285825926556432, details={'was_impossible': False}),
#  Prediction(uid='12', iid='127', r_ui=4.0, est=4.553933959408334, details={'was_impossible': False}),
#  Prediction(uid='12', iid='203', r_ui=3.0, est=4.268263123033422, details={'was_impossible': False}),
#  Prediction(uid='12', iid='480', r_ui=4.0, est=4.565695471826206, details={'was_impossible': False}),
#  Prediction(uid='13', iid='8', r_ui=4.0, est=3.5261936717645095, details={'was_impossible': False}),
#  Prediction(uid='13', iid='9', r_ui=3.0, est=3.404276883733805, details={'was_impossible': False}),
#  Prediction(uid='13', iid='28', r_ui=5.0, est=3.4582126927805272, details={'was_impossible': False}),
#  Prediction(uid='13', iid='60', r_ui=4.0, est=3.522791030928101, details={'was_impossible': False}),
#  Prediction(uid='13', iid='116', r_ui=5.0, est=3.365300855803163, details={'was_impossible': False}),
#  Prediction(uid='13', iid='135', r_ui=5.0, est=3.491601308818792, details={'was_impossible': False}),
#  Prediction(uid='13', iid='141', r_ui=2.0, est=3.1685201292460112, details={'was_impossible': False}),
#  Prediction(uid='13', iid='166', r_ui=5.0, est=3.55797726460055, details={'was_impossible': False}),
#  Prediction(uid='13', iid='176', r_ui=3.0, est=3.481360893108223, details={'was_impossible': False}),
#  Prediction(uid='13', iid='182', r_ui=5.0, est=3.4803738477343127, details={'was_impossible': False}),
#  Prediction(uid='13', iid='188', r_ui=4.0, est=3.270639495376489, details={'was_impossible': False}),
#  Prediction(uid='13', iid='218', r_ui=1.0, est=3.121914102670794, details={'was_impossible': False}),
#  Prediction(uid='13', iid='225', r_ui=2.0, est=2.7748875664494874, details={'was_impossible': False}),
#  Prediction(uid='13', iid='242', r_ui=2.0, est=3.574290590760624, details={'was_impossible': False}),
#  Prediction(uid='13', iid='260', r_ui=1.0, est=2.4536511383446333, details={'was_impossible': False}),
#  Prediction(uid='13', iid='280', r_ui=4.0, est=2.8752310375529233, details={'was_impossible': False}),
#  Prediction(uid='13', iid='285', r_ui=5.0, est=3.7255165843845757, details={'was_impossible': False}),
#  Prediction(uid='13', iid='336', r_ui=2.0, est=2.731362858064754, details={'was_impossible': False}),
#  Prediction(uid='13', iid='358', r_ui=3.0, est=2.5548679712006854, details={'was_impossible': False}),
#  Prediction(uid='13', iid='362', r_ui=4.0, est=2.797059469618038, details={'was_impossible': False}),
#  Prediction(uid='13', iid='400', r_ui=4.0, est=2.723374652912783, details={'was_impossible': False}),
#  Prediction(uid='13', iid='429', r_ui=5.0, est=3.499752283707894, details={'was_impossible': False}),
#  Prediction(uid='13', iid='432', r_ui=4.0, est=3.276338866583713, details={'was_impossible': False}),
#  Prediction(uid='13', iid='445', r_ui=4.0, est=3.2137658556811055, details={'was_impossible': False}),
#  Prediction(uid='13', iid='446', r_ui=1.0, est=3.00868030055753, details={'was_impossible': False}),
#  Prediction(uid='13', iid='515', r_ui=2.0, est=3.687341435717344, details={'was_impossible': False}),
#  Prediction(uid='13', iid='522', r_ui=5.0, est=3.3209560249320322, details={'was_impossible': False}),
#  Prediction(uid='13', iid='525', r_ui=5.0, est=3.468396136786864, details={'was_impossible': False}),
#  Prediction(uid='13', iid='541', r_ui=1.0, est=2.8160127596208517, details={'was_impossible': False}),
#  Prediction(uid='13', iid='549', r_ui=4.0, est=3.1661883849981836, details={'was_impossible': False}),
#  Prediction(uid='13', iid='590', r_ui=2.0, est=2.529748824852985, details={'was_impossible': False}),
#  Prediction(uid='13', iid='629', r_ui=1.0, est=3.099318015108194, details={'was_impossible': False}),
#  Prediction(uid='13', iid='671', r_ui=3.0, est=3.2179880921682256, details={'was_impossible': False}),
#  Prediction(uid='13', iid='756', r_ui=2.0, est=2.6413705840714217, details={'was_impossible': False}),
#  Prediction(uid='13', iid='778', r_ui=3.0, est=3.207275159483143, details={'was_impossible': False}),
#  Prediction(uid='13', iid='793', r_ui=5.0, est=3.150011690829232, details={'was_impossible': False}),
#  Prediction(uid='13', iid='798', r_ui=2.0, est=2.830568989569211, details={'was_impossible': False}),
#  Prediction(uid='13', iid='803', r_ui=3.0, est=2.886790504862082, details={'was_impossible': False}),
#  Prediction(uid='13', iid='811', r_ui=5.0, est=3.3734330601738645, details={'was_impossible': False}),
#  Prediction(uid='13', iid='813', r_ui=1.0, est=3.447671468841061, details={'was_impossible': False}),
#  Prediction(uid='13', iid='822', r_ui=3.0, est=3.115253615423108, details={'was_impossible': False}),
#  Prediction(uid='13', iid='825', r_ui=1.0, est=2.845205022430327, details={'was_impossible': False}),
#  Prediction(uid='13', iid='834', r_ui=1.0, est=2.6204235248518, details={'was_impossible': False}),
#  Prediction(uid='13', iid='837', r_ui=4.0, est=3.2839425585410917, details={'was_impossible': False}),
#  Prediction(uid='13', iid='841', r_ui=1.0, est=2.719415863941021, details={'was_impossible': False}),
#  Prediction(uid='13', iid='870', r_ui=3.0, est=3.0422386475729395, details={'was_impossible': False}),
#  Prediction(uid='13', iid='882', r_ui=3.0, est=3.1547371358159717, details={'was_impossible': False}),
#  Prediction(uid='13', iid='893', r_ui=3.0, est=2.8701281529912612, details={'was_impossible': False}),
#  Prediction(uid='13', iid='899', r_ui=1.0, est=3.228128439877997, details={'was_impossible': False}),
#  Prediction(uid='13', iid='904', r_ui=1.0, est=3.3470780002965648, details={'was_impossible': False}),
#  Prediction(uid='13', iid='905', r_ui=2.0, est=3.047222135189956, details={'was_impossible': False}),
#  Prediction(uid='14', iid='19', r_ui=5.0, est=4.029658090919735, details={'was_impossible': False}),
#  Prediction(uid='14', iid='25', r_ui=2.0, est=3.730740879650991, details={'was_impossible': False}),
#  Prediction(uid='14', iid='276', r_ui=4.0, est=3.8349677591935856, details={'was_impossible': False}),
#  Prediction(uid='14', iid='382', r_ui=5.0, est=3.7796214738392497, details={'was_impossible': False}),
#  Prediction(uid='14', iid='524', r_ui=5.0, est=4.045589756743139, details={'was_impossible': False}),
#  Prediction(uid='14', iid='525', r_ui=5.0, est=4.039071024180211, details={'was_impossible': False}),
#  Prediction(uid='14', iid='588', r_ui=4.0, est=3.9212419780455257, details={'was_impossible': False}),
#  Prediction(uid='14', iid='663', r_ui=5.0, est=4.063140038192038, details={'was_impossible': False}),
#  Prediction(uid='15', iid='225', r_ui=3.0, est=2.718634256620752, details={'was_impossible': False}),
#  Prediction(uid='15', iid='322', r_ui=3.0, est=2.8353853292403857, details={'was_impossible': False}),
#  Prediction(uid='15', iid='845', r_ui=2.0, est=3.0839436357937786, details={'was_impossible': False}),
#  Prediction(uid='15', iid='938', r_ui=3.0, est=2.777432790383168, details={'was_impossible': False}),
#  Prediction(uid='16', iid='33', r_ui=2.0, est=3.9334087453668776, details={'was_impossible': False}),
#  Prediction(uid='16', iid='39', r_ui=5.0, est=3.8010656957838114, details={'was_impossible': False}),
#  Prediction(uid='16', iid='66', r_ui=4.0, est=4.023604966334684, details={'was_impossible': False}),
#  Prediction(uid='16', iid='127', r_ui=5.0, est=4.503430059876617, details={'was_impossible': False}),
#  Prediction(uid='16', iid='135', r_ui=4.0, est=4.278127549326648, details={'was_impossible': False}),
#  Prediction(uid='16', iid='367', r_ui=3.0, est=3.937893603107395, details={'was_impossible': False}),
#  Prediction(uid='16', iid='410', r_ui=5.0, est=3.702494840581829, details={'was_impossible': False}),
#  Prediction(uid='16', iid='480', r_ui=5.0, est=4.518665491172949, details={'was_impossible': False}),
#  Prediction(uid='16', iid='943', r_ui=3.0, est=4.086842974662407, details={'was_impossible': False}),
#  Prediction(uid='17', iid='222', r_ui=3.0, est=3.2825703245821445, details={'was_impossible': False}),
#  Prediction(uid='17', iid='269', r_ui=4.0, est=3.4766187951622713, details={'was_impossible': False}),
#  Prediction(uid='17', iid='276', r_ui=4.0, est=3.2480502845629586, details={'was_impossible': False}),
#  Prediction(uid='18', iid='15', r_ui=4.0, est=3.762471139766768, details={'was_impossible': False}),
#  Prediction(uid='18', iid='28', r_ui=3.0, est=3.8888266286107642, details={'was_impossible': False}),
#  Prediction(uid='18', iid='50', r_ui=4.0, est=4.219874394586877, details={'was_impossible': False}),
#  Prediction(uid='18', iid='56', r_ui=5.0, est=3.9176017239235645, details={'was_impossible': False}),
#  Prediction(uid='18', iid='83', r_ui=5.0, est=3.9659668857839616, details={'was_impossible': False}),
#  Prediction(uid='18', iid='116', r_ui=5.0, est=3.7957817603583988, details={'was_impossible': False}),
#  Prediction(uid='18', iid='127', r_ui=5.0, est=4.148401735967189, details={'was_impossible': False}),
#  Prediction(uid='18', iid='133', r_ui=5.0, est=3.908858868833038, details={'was_impossible': False}),
#  Prediction(uid='18', iid='142', r_ui=4.0, est=3.3889385605443803, details={'was_impossible': False}),
#  Prediction(uid='18', iid='174', r_ui=4.0, est=4.12594046433918, details={'was_impossible': False}),
#  Prediction(uid='18', iid='187', r_ui=5.0, est=4.126896659356153, details={'was_impossible': False}),
#  Prediction(uid='18', iid='212', r_ui=5.0, est=3.4738841930853184, details={'was_impossible': False}),
#  Prediction(uid='18', iid='317', r_ui=5.0, est=3.8949531803578097, details={'was_impossible': False}),
#  Prediction(uid='18', iid='357', r_ui=4.0, est=4.149128218244414, details={'was_impossible': False}),
#  Prediction(uid='18', iid='381', r_ui=4.0, est=3.611641282217693, details={'was_impossible': False}),
#  Prediction(uid='18', iid='604', r_ui=5.0, est=3.9902232030811224, details={'was_impossible': False}),
#  Prediction(uid='18', iid='612', r_ui=4.0, est=3.8274931498871347, details={'was_impossible': False}),
#  Prediction(uid='18', iid='724', r_ui=4.0, est=3.592637460800488, details={'was_impossible': False}),
#  Prediction(uid='18', iid='952', r_ui=2.0, est=3.4123550311682114, details={'was_impossible': False}),
#  Prediction(uid='18', iid='959', r_ui=3.0, est=3.774648536934285, details={'was_impossible': False}),
#  Prediction(uid='18', iid='962', r_ui=4.0, est=3.3907409448322894, details={'was_impossible': False}),
#  Prediction(uid='18', iid='967', r_ui=3.0, est=3.476607230535221, details={'was_impossible': False}),
#  Prediction(uid='19', iid='294', r_ui=3.0, est=3.299758279483319, details={'was_impossible': False}),
#  Prediction(uid='20', iid='15', r_ui=4.0, est=3.2600324789929647, details={'was_impossible': False}),
#  Prediction(uid='20', iid='22', r_ui=5.0, est=3.5674166910920406, details={'was_impossible': False}),
#  Prediction(uid='20', iid='50', r_ui=3.0, est=3.7140125505155006, details={'was_impossible': False}),
#  Prediction(uid='20', iid='82', r_ui=4.0, est=3.2866208474924976, details={'was_impossible': False}),
#  Prediction(uid='20', iid='204', r_ui=3.0, est=3.3014910348683557, details={'was_impossible': False}),
#  Prediction(uid='20', iid='243', r_ui=4.0, est=2.351100702803288, details={'was_impossible': False}),
#  Prediction(uid='20', iid='323', r_ui=4.0, est=2.7211068562780505, details={'was_impossible': False}),
#  Prediction(uid='21', iid='1', r_ui=5.0, est=3.223629156464063, details={'was_impossible': False}),
#  Prediction(uid='21', iid='9', r_ui=5.0, est=3.2073816791875065, details={'was_impossible': False}),
#  Prediction(uid='21', iid='15', r_ui=4.0, est=3.13511559478626, details={'was_impossible': False}),
#  Prediction(uid='21', iid='53', r_ui=4.0, est=2.6511206155462497, details={'was_impossible': False}),
#  Prediction(uid='21', iid='127', r_ui=5.0, est=3.520572181412675, details={'was_impossible': False}),
#  Prediction(uid='21', iid='264', r_ui=3.0, est=2.418243772260469, details={'was_impossible': False}),
#  Prediction(uid='21', iid='273', r_ui=4.0, est=3.038247891342613, details={'was_impossible': False}),
#  Prediction(uid='21', iid='286', r_ui=3.0, est=3.050512992982362, details={'was_impossible': False}),
#  Prediction(uid='21', iid='321', r_ui=3.0, est=2.7508061913539708, details={'was_impossible': False}),
#  Prediction(uid='21', iid='323', r_ui=2.0, est=2.601292472712018, details={'was_impossible': False}),
#  Prediction(uid='21', iid='330', r_ui=4.0, est=2.7046021316005726, details={'was_impossible': False}),
#  Prediction(uid='21', iid='408', r_ui=5.0, est=3.7211376664879654, details={'was_impossible': False}),
#  Prediction(uid='21', iid='672', r_ui=3.0, est=2.449591545168126, details={'was_impossible': False}),
#  Prediction(uid='21', iid='858', r_ui=1.0, est=2.8004165831855317, details={'was_impossible': False}),
#  Prediction(uid='21', iid='873', r_ui=2.0, est=2.6252219762554128, details={'was_impossible': False}),
#  Prediction(uid='21', iid='876', r_ui=2.0, est=2.4388873866908707, details={'was_impossible': False}),
#  Prediction(uid='21', iid='877', r_ui=2.0, est=2.370878595561189, details={'was_impossible': False}),
#  Prediction(uid='21', iid='987', r_ui=3.0, est=2.8901388310540908, details={'was_impossible': False}),
#  Prediction(uid='21', iid='991', r_ui=2.0, est=2.397275241397588, details={'was_impossible': False}),
#  Prediction(uid='22', iid='68', r_ui=4.0, est=3.363964939169221, details={'was_impossible': False}),
#  Prediction(uid='22', iid='174', r_ui=5.0, est=3.883107541936007, details={'was_impossible': False}),
#  Prediction(uid='22', iid='209', r_ui=4.0, est=3.6660367931808855, details={'was_impossible': False}),
#  Prediction(uid='22', iid='233', r_ui=3.0, est=3.113557049070284, details={'was_impossible': False}),
#  Prediction(uid='22', iid='265', r_ui=3.0, est=3.6089719063469112, details={'was_impossible': False}),
#  Prediction(uid='22', iid='385', r_ui=4.0, est=3.4256014053574066, details={'was_impossible': False}),
#  Prediction(uid='22', iid='526', r_ui=4.0, est=3.6214911243262113, details={'was_impossible': False}),
#  Prediction(uid='22', iid='731', r_ui=3.0, est=3.140600901786166, details={'was_impossible': False}),
#  Prediction(uid='22', iid='792', r_ui=4.0, est=3.5422978386600246, details={'was_impossible': False}),
#  Prediction(uid='22', iid='998', r_ui=1.0, est=3.035550106022515, details={'was_impossible': False}),
#  Prediction(uid='23', iid='73', r_ui=3.0, est=3.4571180414498985, details={'was_impossible': False}),
#  Prediction(uid='23', iid='173', r_ui=5.0, est=4.017641133764611, details={'was_impossible': False}),
#  Prediction(uid='23', iid='176', r_ui=3.0, est=3.8237988391732163, details={'was_impossible': False}),
#  Prediction(uid='23', iid='181', r_ui=4.0, est=3.9074115486550443, details={'was_impossible': False}),
#  Prediction(uid='23', iid='227', r_ui=3.0, est=3.4087783743210105, details={'was_impossible': False}),
#  Prediction(uid='23', iid='387', r_ui=3.0, est=3.4305870621361345, details={'was_impossible': False}),
#  Prediction(uid='23', iid='449', r_ui=2.0, est=3.21175966132783, details={'was_impossible': False}),
#  Prediction(uid='23', iid='451', r_ui=2.0, est=3.3734233440375396, details={'was_impossible': False}),
#  Prediction(uid='23', iid='603', r_ui=4.0, est=4.099118577014627, details={'was_impossible': False}),
#  Prediction(uid='23', iid='642', r_ui=3.0, est=3.494414100644738, details={'was_impossible': False}),
#  Prediction(uid='23', iid='919', r_ui=5.0, est=3.700398261797344, details={'was_impossible': False}),
#  Prediction(uid='24', iid='7', r_ui=4.0, est=4.178590542977785, details={'was_impossible': False}),
#  Prediction(uid='24', iid='58', r_ui=3.0, est=4.0687891393045135, details={'was_impossible': False}),
#  Prediction(uid='24', iid='97', r_ui=4.0, est=4.1550005340966045, details={'was_impossible': False}),
#  Prediction(uid='24', iid='151', r_ui=5.0, est=4.048777035554625, details={'was_impossible': False}),
#  Prediction(uid='24', iid='223', r_ui=5.0, est=4.422114080899638, details={'was_impossible': False}),
#  Prediction(uid='24', iid='276', r_ui=5.0, est=4.043915342993143, details={'was_impossible': False}),
#  Prediction(uid='24', iid='324', r_ui=5.0, est=3.718708753583192, details={'was_impossible': False}),
#  Prediction(uid='24', iid='518', r_ui=4.0, est=4.056083229606501, details={'was_impossible': False}),
#  Prediction(uid='24', iid='699', r_ui=3.0, est=4.07164326560307, details={'was_impossible': False}),
#  Prediction(uid='24', iid='1007', r_ui=5.0, est=4.389527368363381, details={'was_impossible': False}),
#  Prediction(uid='25', iid='7', r_ui=4.0, est=3.93569105584368, details={'was_impossible': False}),
#  Prediction(uid='25', iid='79', r_ui=4.0, est=4.057488741441966, details={'was_impossible': False}),
#  Prediction(uid='25', iid='82', r_ui=4.0, est=3.9011774935307852, details={'was_impossible': False}),
#  Prediction(uid='25', iid='86', r_ui=4.0, est=4.018482459039528, details={'was_impossible': False}),
#  Prediction(uid='25', iid='125', r_ui=5.0, est=3.742396886510405, details={'was_impossible': False}),
#  Prediction(uid='25', iid='176', r_ui=4.0, est=4.021723377708591, details={'was_impossible': False}),
#  Prediction(uid='25', iid='177', r_ui=3.0, est=3.966914384820032, details={'was_impossible': False}),
#  Prediction(uid='25', iid='612', r_ui=4.0, est=3.9449368587980005, details={'was_impossible': False}),
#  Prediction(uid='25', iid='657', r_ui=4.0, est=4.240600490930404, details={'was_impossible': False}),
#  Prediction(uid='25', iid='692', r_ui=4.0, est=3.7950531608490023, details={'was_impossible': False}),
#  Prediction(uid='26', iid='122', r_ui=1.0, est=2.3686763399579847, details={'was_impossible': False}),
#  Prediction(uid='26', iid='248', r_ui=3.0, est=3.3058903152920256, details={'was_impossible': False}),
#  Prediction(uid='26', iid='282', r_ui=4.0, est=3.2569006962917872, details={'was_impossible': False}),
#  Prediction(uid='26', iid='288', r_ui=4.0, est=3.082052339040525, details={'was_impossible': False}),
#  Prediction(uid='26', iid='323', r_ui=2.0, est=2.7885560849630897, details={'was_impossible': False}),
#  Prediction(uid='26', iid='328', r_ui=2.0, est=3.1060536288961034, details={'was_impossible': False}),
#  Prediction(uid='26', iid='471', r_ui=2.0, est=3.248030154775309, details={'was_impossible': False}),
#  Prediction(uid='26', iid='515', r_ui=4.0, est=3.6784917021582983, details={'was_impossible': False}),
#  Prediction(uid='26', iid='683', r_ui=3.0, est=2.4891686618183333, details={'was_impossible': False}),
#  Prediction(uid='26', iid='760', r_ui=1.0, est=2.5838083740208875, details={'was_impossible': False}),
#  Prediction(uid='26', iid='845', r_ui=3.0, est=3.137471717694495, details={'was_impossible': False}),
#  Prediction(uid='26', iid='936', r_ui=4.0, est=3.5247765424772615, details={'was_impossible': False}),
#  Prediction(uid='26', iid='1010', r_ui=2.0, est=3.1291338066301644, details={'was_impossible': False}),
#  Prediction(uid='26', iid='1013', r_ui=1.0, est=2.4923330575353115, details={'was_impossible': False}),
#  Prediction(uid='27', iid='123', r_ui=5.0, est=3.1274292195588353, details={'was_impossible': False}),
#  Prediction(uid='27', iid='1017', r_ui=4.0, est=3.204322157184896, details={'was_impossible': False}),
#  Prediction(uid='28', iid='196', r_ui=4.0, est=3.9414875842486503, details={'was_impossible': False}),
#  Prediction(uid='28', iid='434', r_ui=4.0, est=3.848552180724516, details={'was_impossible': False}),
#  Prediction(uid='28', iid='444', r_ui=3.0, est=3.282068265431409, details={'was_impossible': False}),
#  Prediction(uid='28', iid='529', r_ui=4.0, est=3.9456035404208505, details={'was_impossible': False}),
#  Prediction(uid='28', iid='588', r_ui=3.0, est=3.807368553117686, details={'was_impossible': False}),
#  Prediction(uid='28', iid='603', r_ui=3.0, est=4.218129285024692, details={'was_impossible': False}),
#  Prediction(uid='30', iid='29', r_ui=3.0, est=3.1430789243293193, details={'was_impossible': False}),
#  Prediction(uid='30', iid='69', r_ui=5.0, est=3.9424880865229173, details={'was_impossible': False}),
#  Prediction(uid='30', iid='135', r_ui=5.0, est=3.986479392668153, details={'was_impossible': False}),
#  Prediction(uid='30', iid='319', r_ui=4.0, est=3.526504689842238, details={'was_impossible': False}),
#  Prediction(uid='30', iid='780', r_ui=4.0, est=3.3326982997613417, details={'was_impossible': False}),
#  Prediction(uid='31', iid='192', r_ui=4.0, est=4.081475457253483, details={'was_impossible': False}),
#  Prediction(uid='31', iid='611', r_ui=4.0, est=4.053373061167138, details={'was_impossible': False}),
#  Prediction(uid='32', iid='50', r_ui=4.0, est=4.003129816268007, details={'was_impossible': False}),
#  Prediction(uid='32', iid='181', r_ui=4.0, est=3.7770233060753067, details={'was_impossible': False}),
#  Prediction(uid='32', iid='408', r_ui=3.0, est=4.132203859018885, details={'was_impossible': False}),
#  Prediction(uid='32', iid='628', r_ui=4.0, est=3.3753639157208064, details={'was_impossible': False}),
#  Prediction(uid='33', iid='288', r_ui=4.0, est=3.5979138379276736, details={'was_impossible': False}),
#  Prediction(uid='33', iid='300', r_ui=4.0, est=3.768763759879827, details={'was_impossible': False}),
#  Prediction(uid='34', iid='288', r_ui=2.0, est=3.833466119921276, details={'was_impossible': False}),
#  Prediction(uid='34', iid='289', r_ui=1.0, est=3.5372029870098154, details={'was_impossible': False}),
#  Prediction(uid='34', iid='898', r_ui=5.0, est=3.78472069777664, details={'was_impossible': False}),
#  Prediction(uid='34', iid='899', r_ui=5.0, est=3.9164521579349385, details={'was_impossible': False}),
#  Prediction(uid='34', iid='991', r_ui=4.0, est=3.2948404578612482, details={'was_impossible': False}),
#  Prediction(uid='35', iid='321', r_ui=3.0, est=3.13454704889068, details={'was_impossible': False}),
#  Prediction(uid='37', iid='62', r_ui=5.0, est=3.3843230991555613, details={'was_impossible': False}),
#  Prediction(uid='37', iid='121', r_ui=2.0, est=3.5980101532246618, details={'was_impossible': False}),
#  Prediction(uid='37', iid='226', r_ui=5.0, est=3.5412539723272287, details={'was_impossible': False}),
#  Prediction(uid='37', iid='233', r_ui=4.0, est=3.3819541737185084, details={'was_impossible': False}),
#  Prediction(uid='37', iid='472', r_ui=2.0, est=3.386126412814079, details={'was_impossible': False}),
#  Prediction(uid='37', iid='568', r_ui=3.0, est=3.7087223422532443, details={'was_impossible': False}),
#  Prediction(uid='38', iid='162', r_ui=5.0, est=3.863934799162711, details={'was_impossible': False}),
#  Prediction(uid='38', iid='185', r_ui=2.0, est=4.124359779457, details={'was_impossible': False}),
#  Prediction(uid='38', iid='195', r_ui=1.0, est=4.000710353527764, details={'was_impossible': False}),
#  Prediction(uid='38', iid='413', r_ui=1.0, est=3.2295847931113624, details={'was_impossible': False}),
#  Prediction(uid='38', iid='420', r_ui=5.0, est=3.801798561669617, details={'was_impossible': False}),
#  Prediction(uid='38', iid='433', r_ui=5.0, est=3.8257259091829425, details={'was_impossible': False}),
#  Prediction(uid='38', iid='447', r_ui=5.0, est=3.7416926529387893, details={'was_impossible': False}),
#  Prediction(uid='38', iid='451', r_ui=5.0, est=3.5932714327886948, details={'was_impossible': False}),
#  Prediction(uid='38', iid='627', r_ui=5.0, est=3.4943619519600477, details={'was_impossible': False}),
#  Prediction(uid='38', iid='673', r_ui=5.0, est=3.7091101593165914, details={'was_impossible': False}),
#  Prediction(uid='38', iid='678', r_ui=5.0, est=3.2145408576125734, details={'was_impossible': False}),
#  Prediction(uid='38', iid='768', r_ui=5.0, est=3.4087469403557176, details={'was_impossible': False}),
#  Prediction(uid='38', iid='1029', r_ui=1.0, est=3.1243936203599785, details={'was_impossible': False}),
#  Prediction(uid='38', iid='1032', r_ui=4.0, est=3.442982708460342, details={'was_impossible': False}),
#  Prediction(uid='38', iid='1037', r_ui=4.0, est=3.1046692204828985, details={'was_impossible': False}),
#  Prediction(uid='39', iid='288', r_ui=5.0, est=3.4854935801520797, details={'was_impossible': False}),
#  Prediction(uid='39', iid='302', r_ui=5.0, est=4.04631504569373, details={'was_impossible': False}),
#  Prediction(uid='39', iid='319', r_ui=4.0, est=3.4108951068219975, details={'was_impossible': False}),
#  Prediction(uid='40', iid='302', r_ui=3.0, est=3.642332047484606, details={'was_impossible': False}),
#  Prediction(uid='40', iid='346', r_ui=2.0, est=3.3300766026098736, details={'was_impossible': False}),
#  Prediction(uid='41', iid='50', r_ui=5.0, est=4.080864964621232, details={'was_impossible': False}),
#  Prediction(uid='41', iid='135', r_ui=4.0, est=3.7858255798235105, details={'was_impossible': False}),
#  Prediction(uid='41', iid='156', r_ui=4.0, est=3.7894437252826085, details={'was_impossible': False}),
#  Prediction(uid='41', iid='173', r_ui=4.0, est=3.9655132624121885, details={'was_impossible': False}),
#  Prediction(uid='41', iid='191', r_ui=4.0, est=3.8621311781530374, details={'was_impossible': False}),
#  Prediction(uid='41', iid='205', r_ui=4.0, est=3.7960706619761497, details={'was_impossible': False}),
#  Prediction(uid='41', iid='514', r_ui=4.0, est=3.7867820929953675, details={'was_impossible': False}),
#  Prediction(uid='41', iid='969', r_ui=4.0, est=3.654903428815146, details={'was_impossible': False}),
#  Prediction(uid='42', iid='2', r_ui=5.0, est=3.433832469383298, details={'was_impossible': False}),
#  Prediction(uid='42', iid='87', r_ui=4.0, est=3.9488823561658117, details={'was_impossible': False}),
#  Prediction(uid='42', iid='103', r_ui=3.0, est=2.918284823741916, details={'was_impossible': False}),
#  Prediction(uid='42', iid='136', r_ui=4.0, est=4.01397435615526, details={'was_impossible': False}),
#  Prediction(uid='42', iid='168', r_ui=3.0, est=4.035873640242114, details={'was_impossible': False}),
#  Prediction(uid='42', iid='282', r_ui=4.0, est=3.70005153406354, details={'was_impossible': False}),
#  Prediction(uid='42', iid='411', r_ui=4.0, est=3.1800197573814475, details={'was_impossible': False}),
#  Prediction(uid='42', iid='433', r_ui=2.0, est=3.6984517529131695, details={'was_impossible': False}),
#  Prediction(uid='42', iid='591', r_ui=4.0, est=3.6446566200908777, details={'was_impossible': False}),
#  Prediction(uid='42', iid='658', r_ui=2.0, est=3.5522218580755047, details={'was_impossible': False}),
#  Prediction(uid='42', iid='735', r_ui=4.0, est=3.8158898108696446, details={'was_impossible': False}),
#  Prediction(uid='42', iid='755', r_ui=4.0, est=3.488638265919254, details={'was_impossible': False}),
#  Prediction(uid='43', iid='73', r_ui=4.0, est=3.544088434780966, details={'was_impossible': False}),
#  Prediction(uid='43', iid='123', r_ui=1.0, est=3.423549664666744, details={'was_impossible': False}),
#  Prediction(uid='43', iid='143', r_ui=4.0, est=3.7788510258532013, details={'was_impossible': False}),
#  Prediction(uid='43', iid='202', r_ui=5.0, est=3.803141855564698, details={'was_impossible': False}),
#  Prediction(uid='43', iid='226', r_ui=3.0, est=3.5224362135074063, details={'was_impossible': False}),
#  Prediction(uid='43', iid='254', r_ui=3.0, est=2.908042608778675, details={'was_impossible': False}),
#  Prediction(uid='43', iid='580', r_ui=3.0, est=3.473255319162055, details={'was_impossible': False}),
#  Prediction(uid='43', iid='591', r_ui=5.0, est=3.638893117208187, details={'was_impossible': False}),
#  Prediction(uid='43', iid='731', r_ui=4.0, est=3.38645456072338, details={'was_impossible': False}),
#  Prediction(uid='43', iid='892', r_ui=3.0, est=3.0320229507432344, details={'was_impossible': False}),
#  Prediction(uid='43', iid='1055', r_ui=2.0, est=3.568344593044539, details={'was_impossible': False}),
#  Prediction(uid='44', iid='22', r_ui=4.0, est=3.9903811044491273, details={'was_impossible': False}),
#  Prediction(uid='44', iid='31', r_ui=4.0, est=3.5919102384809816, details={'was_impossible': False}),
#  Prediction(uid='44', iid='97', r_ui=2.0, est=3.7253501427488604, details={'was_impossible': False}),
#  Prediction(uid='44', iid='151', r_ui=4.0, est=3.617316608176472, details={'was_impossible': False}),
#  Prediction(uid='44', iid='173', r_ui=5.0, est=4.029326387240074, details={'was_impossible': False}),
#  Prediction(uid='44', iid='175', r_ui=4.0, est=3.774896099225172, details={'was_impossible': False}),
#  Prediction(uid='44', iid='181', r_ui=4.0, est=3.9183142542875053, details={'was_impossible': False}),
#  Prediction(uid='44', iid='183', r_ui=4.0, est=3.885922638239046, details={'was_impossible': False}),
#  Prediction(uid='44', iid='190', r_ui=5.0, est=4.000245224271702, details={'was_impossible': False}),
#  Prediction(uid='44', iid='198', r_ui=4.0, est=3.862737664439112, details={'was_impossible': False}),
#  Prediction(uid='44', iid='201', r_ui=2.0, est=3.5336789086827256, details={'was_impossible': False}),
#  Prediction(uid='44', iid='307', r_ui=4.0, est=3.5776474929509354, details={'was_impossible': False}),
#  Prediction(uid='44', iid='318', r_ui=5.0, est=4.216622409869819, details={'was_impossible': False}),
#  Prediction(uid='44', iid='432', r_ui=5.0, est=3.628638390070405, details={'was_impossible': False}),
#  Prediction(uid='44', iid='633', r_ui=3.0, est=3.830313358800213, details={'was_impossible': False}),
#  Prediction(uid='44', iid='692', r_ui=3.0, est=3.61259821175887, details={'was_impossible': False}),
#  Prediction(uid='45', iid='24', r_ui=3.0, est=3.6182159687405426, details={'was_impossible': False}),
#  Prediction(uid='45', iid='764', r_ui=4.0, est=3.0821955685821303, details={'was_impossible': False}),
#  Prediction(uid='45', iid='826', r_ui=3.0, est=2.9151936737032176, details={'was_impossible': False}),
#  Prediction(uid='45', iid='993', r_ui=4.0, est=3.594589903937937, details={'was_impossible': False}),
#  Prediction(uid='46', iid='262', r_ui=5.0, est=3.961202584787426, details={'was_impossible': False}),
#  Prediction(uid='46', iid='286', r_ui=5.0, est=3.866398417906238, details={'was_impossible': False}),
#  Prediction(uid='47', iid='262', r_ui=5.0, est=3.7034696643962453, details={'was_impossible': False}),
#  Prediction(uid='47', iid='305', r_ui=5.0, est=3.573909869692168, details={'was_impossible': False}),
#  Prediction(uid='47', iid='1022', r_ui=3.0, est=3.6197391054327275, details={'was_impossible': False}),
#  Prediction(uid='48', iid='193', r_ui=2.0, est=3.8475300759841593, details={'was_impossible': False}),
#  Prediction(uid='48', iid='302', r_ui=4.0, est=4.0656913145734075, details={'was_impossible': False}),
#  Prediction(uid='48', iid='428', r_ui=4.0, est=3.850663341374536, details={'was_impossible': False}),
#  Prediction(uid='48', iid='650', r_ui=3.0, est=3.548119233673969, details={'was_impossible': False}),
#  Prediction(uid='49', iid='2', r_ui=1.0, est=2.7802837136750833, details={'was_impossible': False}),
#  Prediction(uid='49', iid='12', r_ui=4.0, est=3.580932765372543, details={'was_impossible': False}),
#  Prediction(uid='49', iid='99', r_ui=4.0, est=3.0713471072509155, details={'was_impossible': False}),
#  Prediction(uid='49', iid='121', r_ui=1.0, est=2.926152980453839, details={'was_impossible': False}),
#  Prediction(uid='49', iid='147', r_ui=1.0, est=2.963471310167324, details={'was_impossible': False}),
#  Prediction(uid='49', iid='154', r_ui=5.0, est=3.170038400133232, details={'was_impossible': False}),
#  Prediction(uid='49', iid='174', r_ui=1.0, est=3.4770733964662766, details={'was_impossible': False}),
#  Prediction(uid='49', iid='200', r_ui=3.0, est=3.12465929905918, details={'was_impossible': False}),
#  Prediction(uid='49', iid='208', r_ui=4.0, est=3.2335531824325474, details={'was_impossible': False}),
#  Prediction(uid='49', iid='225', r_ui=2.0, est=2.5541856541480366, details={'was_impossible': False}),
#  Prediction(uid='49', iid='235', r_ui=2.0, est=2.4443267021290462, details={'was_impossible': False}),
#  Prediction(uid='49', iid='256', r_ui=4.0, est=3.093159276094839, details={'was_impossible': False}),
#  Prediction(uid='49', iid='283', r_ui=3.0, est=3.0463065421313877, details={'was_impossible': False}),
#  Prediction(uid='49', iid='289', r_ui=4.0, est=2.5798893575632826, details={'was_impossible': False}),
#  Prediction(uid='49', iid='300', r_ui=1.0, est=3.0394990181187147, details={'was_impossible': False}),
#  Prediction(uid='49', iid='404', r_ui=3.0, est=3.0374751690334727, details={'was_impossible': False}),
#  Prediction(uid='49', iid='475', r_ui=4.0, est=3.23206956053449, details={'was_impossible': False}),
#  Prediction(uid='49', iid='477', r_ui=2.0, est=2.7143444869982223, details={'was_impossible': False}),
#  Prediction(uid='49', iid='577', r_ui=1.0, est=2.250639120892258, details={'was_impossible': False}),
#  Prediction(uid='49', iid='652', r_ui=5.0, est=3.177175177471053, details={'was_impossible': False}),
#  Prediction(uid='49', iid='702', r_ui=3.0, est=2.6357702884260217, details={'was_impossible': False}),
#  Prediction(uid='49', iid='715', r_ui=3.0, est=2.7186219225562165, details={'was_impossible': False}),
#  Prediction(uid='49', iid='789', r_ui=4.0, est=2.9657376976180077, details={'was_impossible': False}),
#  Prediction(uid='49', iid='813', r_ui=3.0, est=3.2200252071349813, details={'was_impossible': False}),
#  Prediction(uid='49', iid='904', r_ui=2.0, est=3.1323624863489976, details={'was_impossible': False}),
#  Prediction(uid='49', iid='1069', r_ui=3.0, est=2.943679716166299, details={'was_impossible': False}),
#  Prediction(uid='49', iid='1073', r_ui=5.0, est=3.137118548943756, details={'was_impossible': False}),
#  Prediction(uid='52', iid='7', r_ui=5.0, est=4.176769967277924, details={'was_impossible': False}),
#  Prediction(uid='52', iid='191', r_ui=5.0, est=4.347957806569083, details={'was_impossible': False}),
#  Prediction(uid='52', iid='277', r_ui=5.0, est=3.9095223210218846, details={'was_impossible': False}),
#  Prediction(uid='52', iid='288', r_ui=3.0, est=3.8644251855509673, details={'was_impossible': False}),
#  Prediction(uid='53', iid='15', r_ui=5.0, est=3.769058333387856, details={'was_impossible': False}),
#  Prediction(uid='54', iid='148', r_ui=3.0, est=3.539767445119074, details={'was_impossible': False}),
#  Prediction(uid='55', iid='7', r_ui=3.0, est=3.585138627358637, details={'was_impossible': False}),
#  Prediction(uid='55', iid='174', r_ui=4.0, est=3.88090480579299, details={'was_impossible': False}),
#  Prediction(uid='56', iid='28', r_ui=5.0, est=3.9240047159499154, details={'was_impossible': False}),
#  Prediction(uid='56', iid='66', r_ui=3.0, est=3.7030088715050042, details={'was_impossible': False}),
#  Prediction(uid='56', iid='193', r_ui=5.0, est=3.90877473467422, details={'was_impossible': False}),
#  Prediction(uid='56', iid='281', r_ui=2.0, est=3.3707084542675108, details={'was_impossible': False}),
#  Prediction(uid='56', iid='295', r_ui=3.0, est=3.5623057968162133, details={'was_impossible': False}),
#  Prediction(uid='56', iid='393', r_ui=4.0, est=3.496366675021954, details={'was_impossible': False}),
#  Prediction(uid='56', iid='405', r_ui=4.0, est=3.508622780233878, details={'was_impossible': False}),
#  Prediction(uid='56', iid='575', r_ui=3.0, est=3.0766054434814323, details={'was_impossible': False}),
#  Prediction(uid='56', iid='636', r_ui=4.0, est=3.570345152540676, details={'was_impossible': False}),
#  Prediction(uid='56', iid='748', r_ui=4.0, est=3.3022460994070686, details={'was_impossible': False}),
#  Prediction(uid='56', iid='871', r_ui=2.0, est=2.9173895017585343, details={'was_impossible': False}),
#  Prediction(uid='56', iid='1074', r_ui=3.0, est=3.2441644169930113, details={'was_impossible': False}),
#  Prediction(uid='56', iid='1091', r_ui=2.0, est=3.170652428230818, details={'was_impossible': False}),
#  Prediction(uid='57', iid='1', r_ui=5.0, est=3.7781781575581155, details={'was_impossible': False}),
#  Prediction(uid='57', iid='121', r_ui=4.0, est=3.5051778729101764, details={'was_impossible': False}),
#  Prediction(uid='57', iid='144', r_ui=3.0, est=3.836870069246542, details={'was_impossible': False}),
#  Prediction(uid='57', iid='168', r_ui=3.0, est=3.9614582900054014, details={'was_impossible': False}),
#  Prediction(uid='57', iid='257', r_ui=5.0, est=3.6385942758454193, details={'was_impossible': False}),
#  Prediction(uid='57', iid='717', r_ui=4.0, est=3.0408184304807517, details={'was_impossible': False}),
#  Prediction(uid='58', iid='7', r_ui=5.0, est=3.7708567691913255, details={'was_impossible': False}),
#  Prediction(uid='58', iid='56', r_ui=5.0, est=3.860340159247649, details={'was_impossible': False}),
#  Prediction(uid='58', iid='168', r_ui=5.0, est=3.9734261033223888, details={'was_impossible': False}),
# ...
#  Prediction(uid='100', iid='751', r_ui=4.0, est=3.162156884521575, details={'was_impossible': False}),
#  Prediction(uid='100', iid='885', r_ui=2.0, est=2.9841702315753404, details={'was_impossible': False}),
#  Prediction(uid='100', iid='898', r_ui=4.0, est=3.0587842325029766, details={'was_impossible': False}),
#  Prediction(uid='101', iid='472', r_ui=3.0, est=2.9722134197482397, details={'was_impossible': False}),
#  Prediction(uid='101', iid='595', r_ui=2.0, est=2.8956390190567673, details={'was_impossible': False}),
#  Prediction(uid='101', iid='763', r_ui=3.0, est=3.180865268667212, details={'was_impossible': False}),
#  Prediction(uid='101', iid='831', r_ui=3.0, est=2.4755570646753453, details={'was_impossible': False}),
#  Prediction(uid='101', iid='1028', r_ui=3.0, est=2.84113403422695, details={'was_impossible': False}),
#  Prediction(uid='102', iid='1', r_ui=3.0, est=3.1262071056783602, details={'was_impossible': False}),
#  Prediction(uid='102', iid='2', r_ui=2.0, est=2.7027978850352854, details={'was_impossible': False}),
#  Prediction(uid='102', iid='7', r_ui=2.0, est=3.1024497935871227, details={'was_impossible': False}),
#  Prediction(uid='102', iid='154', r_ui=3.0, est=3.092725436248917, details={'was_impossible': False}),
#  Prediction(uid='102', iid='172', r_ui=3.0, est=3.3570859933519177, details={'was_impossible': False}),
#  Prediction(uid='102', iid='174', r_ui=4.0, est=3.4010396982389963, details={'was_impossible': False}),
#  Prediction(uid='102', iid='227', r_ui=4.0, est=2.772553309209313, details={'was_impossible': False}),
#  Prediction(uid='102', iid='272', r_ui=3.0, est=3.441200424593125, details={'was_impossible': False}),
#  Prediction(uid='102', iid='301', r_ui=3.0, est=2.675294127845194, details={'was_impossible': False}),
#  Prediction(uid='102', iid='316', r_ui=3.0, est=3.3434812632750686, details={'was_impossible': False}),
#  Prediction(uid='102', iid='684', r_ui=2.0, est=3.094307740417671, details={'was_impossible': False}),
#  Prediction(uid='102', iid='792', r_ui=3.0, est=3.052244667619703, details={'was_impossible': False}),
#  Prediction(uid='102', iid='879', r_ui=3.0, est=2.67746016335885, details={'was_impossible': False}),
#  Prediction(uid='102', iid='1076', r_ui=2.0, est=2.564350848355752, details={'was_impossible': False}),
#  Prediction(uid='103', iid='56', r_ui=5.0, est=3.8252361631937384, details={'was_impossible': False}),
#  Prediction(uid='103', iid='98', r_ui=3.0, est=4.062054497580645, details={'was_impossible': False}),
#  Prediction(uid='104', iid='9', r_ui=2.0, est=3.1596825636142953, details={'was_impossible': False}),
#  Prediction(uid='104', iid='121', r_ui=2.0, est=2.9003866352030228, details={'was_impossible': False}),
#  Prediction(uid='104', iid='310', r_ui=2.0, est=2.9886495640607063, details={'was_impossible': False}),
#  Prediction(uid='104', iid='328', r_ui=3.0, est=2.8656573575785886, details={'was_impossible': False}),
#  Prediction(uid='104', iid='407', r_ui=2.0, est=2.3619974613463004, details={'was_impossible': False}),
#  Prediction(uid='104', iid='471', r_ui=3.0, est=3.0086833799001966, details={'was_impossible': False}),
#  Prediction(uid='104', iid='678', r_ui=2.0, est=2.4114028296220877, details={'was_impossible': False}),
#  Prediction(uid='105', iid='347', r_ui=3.0, est=3.5130101768187014, details={'was_impossible': False}),
#  Prediction(uid='105', iid='751', r_ui=2.0, est=3.4670674403402577, details={'was_impossible': False}),
#  Prediction(uid='105', iid='880', r_ui=3.0, est=3.285605157314063, details={'was_impossible': False}),
#  Prediction(uid='106', iid='9', r_ui=4.0, est=3.802727515836631, details={'was_impossible': False}),
#  Prediction(uid='106', iid='59', r_ui=4.0, est=3.993228748359223, details={'was_impossible': False}),
#  Prediction(uid='106', iid='70', r_ui=3.0, est=3.721754780998691, details={'was_impossible': False}),
#  Prediction(uid='106', iid='82', r_ui=3.0, est=3.7609207859616767, details={'was_impossible': False}),
#  Prediction(uid='106', iid='318', r_ui=5.0, est=4.259960959628962, details={'was_impossible': False}),
#  Prediction(uid='106', iid='463', r_ui=3.0, est=3.800054291621546, details={'was_impossible': False}),
#  Prediction(uid='107', iid='1243', r_ui=3.0, est=3.3501475610493183, details={'was_impossible': False}),
#  Prediction(uid='109', iid='22', r_ui=4.0, est=3.987297300101949, details={'was_impossible': False}),
#  Prediction(uid='109', iid='28', r_ui=3.0, est=3.80850241182193, details={'was_impossible': False}),
#  Prediction(uid='109', iid='50', r_ui=5.0, est=4.13891476256335, details={'was_impossible': False}),
#  Prediction(uid='109', iid='56', r_ui=5.0, est=3.836832095415017, details={'was_impossible': False}),
#  Prediction(uid='109', iid='180', r_ui=3.0, est=3.856080639970816, details={'was_impossible': False}),
#  Prediction(uid='109', iid='250', r_ui=2.0, est=3.4922773789256665, details={'was_impossible': False}),
#  Prediction(uid='109', iid='358', r_ui=2.0, est=2.9047300022873053, details={'was_impossible': False}),
#  Prediction(uid='109', iid='385', r_ui=4.0, est=3.589725842382806, details={'was_impossible': False}),
#  Prediction(uid='109', iid='410', r_ui=1.0, est=3.26739339732819, details={'was_impossible': False}),
#  Prediction(uid='109', iid='476', r_ui=3.0, est=3.161917600643329, details={'was_impossible': False}),
#  Prediction(uid='109', iid='595', r_ui=3.0, est=3.201339051978503, details={'was_impossible': False}),
#  Prediction(uid='109', iid='831', r_ui=2.0, est=2.7791704013609455, details={'was_impossible': False}),
#  Prediction(uid='109', iid='871', r_ui=2.0, est=2.8024509398926893, details={'was_impossible': False}),
#  Prediction(uid='109', iid='924', r_ui=3.0, est=3.483766492661724, details={'was_impossible': False}),
#  Prediction(uid='109', iid='1135', r_ui=4.0, est=3.2054192856242256, details={'was_impossible': False}),
#  Prediction(uid='109', iid='1139', r_ui=2.0, est=3.14576825086682, details={'was_impossible': False}),
#  Prediction(uid='109', iid='1161', r_ui=3.0, est=3.3763934291834015, details={'was_impossible': False}),
#  Prediction(uid='109', iid='1210', r_ui=3.0, est=3.1846379193806413, details={'was_impossible': False}),
#  Prediction(uid='110', iid='29', r_ui=3.0, est=2.719106412080545, details={'was_impossible': False}),
#  Prediction(uid='110', iid='31', r_ui=3.0, est=3.2986737085855142, details={'was_impossible': False}),
#  Prediction(uid='110', iid='67', r_ui=3.0, est=2.962648127568349, details={'was_impossible': False}),
#  Prediction(uid='110', iid='403', r_ui=3.0, est=3.15027296579463, details={'was_impossible': False}),
#  Prediction(uid='110', iid='569', r_ui=4.0, est=2.752003817864226, details={'was_impossible': False}),
#  Prediction(uid='110', iid='576', r_ui=2.0, est=2.8513620643062128, details={'was_impossible': False}),
#  Prediction(uid='110', iid='585', r_ui=2.0, est=2.7982383736781364, details={'was_impossible': False}),
#  Prediction(uid='110', iid='651', r_ui=4.0, est=3.652164965088809, details={'was_impossible': False}),
#  Prediction(uid='110', iid='739', r_ui=4.0, est=3.0813199683538683, details={'was_impossible': False}),
#  Prediction(uid='110', iid='947', r_ui=3.0, est=3.1712047495807307, details={'was_impossible': False}),
#  Prediction(uid='110', iid='1228', r_ui=3.0, est=2.6693409869389533, details={'was_impossible': False}),
#  Prediction(uid='110', iid='1229', r_ui=3.0, est=2.7940764748202214, details={'was_impossible': False}),
#  Prediction(uid='111', iid='304', r_ui=4.0, est=3.4763039030216283, details={'was_impossible': False}),
#  Prediction(uid='112', iid='315', r_ui=5.0, est=4.032189309337097, details={'was_impossible': False}),
#  Prediction(uid='112', iid='332', r_ui=4.0, est=3.5954902323264366, details={'was_impossible': False}),
#  Prediction(uid='112', iid='690', r_ui=4.0, est=3.6561614469656725, details={'was_impossible': False}),
#  Prediction(uid='112', iid='888', r_ui=4.0, est=3.57794311112131, details={'was_impossible': False}),
#  Prediction(uid='113', iid='300', r_ui=3.0, est=3.7667716214486204, details={'was_impossible': False}),
#  Prediction(uid='113', iid='333', r_ui=4.0, est=3.7654359588924082, details={'was_impossible': False}),
#  Prediction(uid='113', iid='742', r_ui=3.0, est=3.7674093376013587, details={'was_impossible': False}),
#  Prediction(uid='113', iid='975', r_ui=5.0, est=3.347200566571154, details={'was_impossible': False}),
#  Prediction(uid='113', iid='979', r_ui=5.0, est=3.566116409653452, details={'was_impossible': False}),
#  Prediction(uid='114', iid='135', r_ui=4.0, est=3.655986355672983, details={'was_impossible': False}),
#  Prediction(uid='114', iid='171', r_ui=4.0, est=3.713103276181355, details={'was_impossible': False}),
#  Prediction(uid='114', iid='172', r_ui=5.0, est=3.8173395378648767, details={'was_impossible': False}),
#  Prediction(uid='114', iid='200', r_ui=3.0, est=3.5057254693665647, details={'was_impossible': False}),
#  Prediction(uid='114', iid='224', r_ui=3.0, est=3.4864337788817656, details={'was_impossible': False}),
#  Prediction(uid='114', iid='522', r_ui=5.0, est=3.4897842536170893, details={'was_impossible': False}),
#  Prediction(uid='114', iid='527', r_ui=3.0, est=3.711702641135521, details={'was_impossible': False}),
#  Prediction(uid='115', iid='83', r_ui=3.0, est=3.985008287639476, details={'was_impossible': False}),
#  Prediction(uid='115', iid='100', r_ui=5.0, est=4.059750261232221, details={'was_impossible': False}),
#  Prediction(uid='115', iid='117', r_ui=4.0, est=3.726762280096625, details={'was_impossible': False}),
#  Prediction(uid='115', iid='185', r_ui=5.0, est=4.006556177246529, details={'was_impossible': False}),
#  Prediction(uid='115', iid='192', r_ui=5.0, est=4.037437130513493, details={'was_impossible': False}),
#  Prediction(uid='115', iid='218', r_ui=3.0, est=3.569271352170462, details={'was_impossible': False}),
#  Prediction(uid='115', iid='302', r_ui=4.0, est=4.1067009589240895, details={'was_impossible': False}),
#  Prediction(uid='115', iid='508', r_ui=5.0, est=3.696217348815651, details={'was_impossible': False}),
#  Prediction(uid='115', iid='558', r_ui=5.0, est=3.7310638663423634, details={'was_impossible': False}),
#  Prediction(uid='115', iid='628', r_ui=5.0, est=3.6088157234808107, details={'was_impossible': False}),
#  Prediction(uid='115', iid='644', r_ui=3.0, est=3.884217385071545, details={'was_impossible': False}),
#  Prediction(uid='115', iid='696', r_ui=4.0, est=3.3599285020340086, details={'was_impossible': False}),
#  Prediction(uid='116', iid='124', r_ui=3.0, est=3.498755399719017, details={'was_impossible': False}),
#  Prediction(uid='116', iid='127', r_ui=5.0, est=3.648159068577585, details={'was_impossible': False}),
#  Prediction(uid='116', iid='269', r_ui=3.0, est=3.425565307509243, details={'was_impossible': False}),
#  Prediction(uid='116', iid='270', r_ui=3.0, est=3.2205257749812874, details={'was_impossible': False}),
#  Prediction(uid='116', iid='275', r_ui=2.0, est=3.417433321199852, details={'was_impossible': False}),
#  Prediction(uid='116', iid='311', r_ui=3.0, est=3.272572078923771, details={'was_impossible': False}),
#  Prediction(uid='116', iid='326', r_ui=2.0, est=3.0016640960390935, details={'was_impossible': False}),
#  Prediction(uid='116', iid='532', r_ui=2.0, est=3.0172284243801983, details={'was_impossible': False}),
#  Prediction(uid='116', iid='596', r_ui=5.0, est=3.042968374316545, details={'was_impossible': False}),
#  Prediction(uid='116', iid='650', r_ui=2.0, est=3.051555259713407, details={'was_impossible': False}),
#  Prediction(uid='116', iid='690', r_ui=3.0, est=3.142583835108091, details={'was_impossible': False}),
#  Prediction(uid='116', iid='1244', r_ui=2.0, est=2.743221518837237, details={'was_impossible': False}),
#  Prediction(uid='117', iid='164', r_ui=5.0, est=3.912126495967486, details={'was_impossible': False}),
#  Prediction(uid='117', iid='249', r_ui=4.0, est=3.5907215512908777, details={'was_impossible': False}),
#  Prediction(uid='117', iid='252', r_ui=3.0, est=3.3701543160118503, details={'was_impossible': False}),
#  Prediction(uid='117', iid='271', r_ui=4.0, est=3.652166256408353, details={'was_impossible': False}),
#  Prediction(uid='117', iid='282', r_ui=5.0, est=3.9197497621398303, details={'was_impossible': False}),
#  Prediction(uid='117', iid='895', r_ui=2.0, est=3.640894833577058, details={'was_impossible': False}),
#  Prediction(uid='117', iid='1059', r_ui=3.0, est=3.572684069566436, details={'was_impossible': False}),
#  Prediction(uid='118', iid='5', r_ui=2.0, est=4.131199024094001, details={'was_impossible': False}),
#  Prediction(uid='118', iid='100', r_ui=5.0, est=4.687804139875596, details={'was_impossible': False}),
#  Prediction(uid='118', iid='179', r_ui=5.0, est=4.527385866622604, details={'was_impossible': False}),
#  Prediction(uid='118', iid='234', r_ui=5.0, est=4.377558419334542, details={'was_impossible': False}),
#  Prediction(uid='118', iid='427', r_ui=5.0, est=4.785759398088163, details={'was_impossible': False}),
#  Prediction(uid='119', iid='93', r_ui=4.0, est=4.008582155905628, details={'was_impossible': False}),
#  Prediction(uid='119', iid='172', r_ui=4.0, est=4.291345842521441, details={'was_impossible': False}),
#  Prediction(uid='119', iid='196', r_ui=5.0, est=4.120752248796121, details={'was_impossible': False}),
#  Prediction(uid='119', iid='257', r_ui=4.0, est=3.9197711280265954, details={'was_impossible': False}),
#  Prediction(uid='119', iid='258', r_ui=2.0, est=4.012384402447473, details={'was_impossible': False}),
#  Prediction(uid='119', iid='271', r_ui=4.0, est=3.6412746431872973, details={'was_impossible': False}),
#  Prediction(uid='119', iid='287', r_ui=4.0, est=3.880889075390474, details={'was_impossible': False}),
#  Prediction(uid='119', iid='315', r_ui=5.0, est=4.232225423609283, details={'was_impossible': False}),
#  Prediction(uid='119', iid='323', r_ui=4.0, est=3.4378119775051976, details={'was_impossible': False}),
#  Prediction(uid='119', iid='349', r_ui=3.0, est=3.5367107732953023, details={'was_impossible': False}),
#  Prediction(uid='119', iid='471', r_ui=4.0, est=3.894424020361186, details={'was_impossible': False}),
#  Prediction(uid='119', iid='492', r_ui=5.0, est=4.030407098369558, details={'was_impossible': False}),
#  Prediction(uid='119', iid='655', r_ui=5.0, est=4.067140366919059, details={'was_impossible': False}),
#  Prediction(uid='119', iid='727', r_ui=5.0, est=3.7405190226066485, details={'was_impossible': False}),
#  Prediction(uid='119', iid='1137', r_ui=5.0, est=4.132277870858137, details={'was_impossible': False}),
#  Prediction(uid='119', iid='1264', r_ui=3.0, est=3.766522390667785, details={'was_impossible': False}),
#  Prediction(uid='120', iid='50', r_ui=4.0, est=4.150495411608771, details={'was_impossible': False}),
#  Prediction(uid='120', iid='118', r_ui=2.0, est=3.2633897575643136, details={'was_impossible': False}),
#  Prediction(uid='120', iid='515', r_ui=5.0, est=4.041679306177731, details={'was_impossible': False}),
#  Prediction(uid='121', iid='1', r_ui=4.0, est=3.7334953989582154, details={'was_impossible': False}),
#  Prediction(uid='121', iid='11', r_ui=2.0, est=3.7546738400168014, details={'was_impossible': False}),
#  Prediction(uid='121', iid='292', r_ui=4.0, est=3.60262183280233, details={'was_impossible': False}),
#  Prediction(uid='121', iid='315', r_ui=4.0, est=3.9106397518646916, details={'was_impossible': False}),
#  Prediction(uid='121', iid='318', r_ui=5.0, est=4.174871129955582, details={'was_impossible': False}),
#  Prediction(uid='121', iid='458', r_ui=1.0, est=3.2344037746503473, details={'was_impossible': False}),
#  Prediction(uid='122', iid='28', r_ui=4.0, est=4.009101324685637, details={'was_impossible': False}),
#  Prediction(uid='122', iid='197', r_ui=5.0, est=4.1040991694097695, details={'was_impossible': False}),
#  Prediction(uid='122', iid='519', r_ui=4.0, est=4.103837514279358, details={'was_impossible': False}),
#  Prediction(uid='122', iid='699', r_ui=5.0, est=3.8514789592681735, details={'was_impossible': False}),
#  Prediction(uid='122', iid='1074', r_ui=4.0, est=3.318336150578866, details={'was_impossible': False}),
#  ...]

# %%
# Then compute RMSE
accuracy.rmse(predictions)
# Out:
# RMSE: 0.9370
# 0.9370026894700734

# %%
# Note that you can train and test an algorithm with the following one-line:
predictions = algo.fit(trainset).test(testset)

# %%
accuracy.rmse(predictions)
# Out:
# RMSE: 0.9367
# 0.9366534632262384

# %% [markdown]
#     1.3 Train on a whole trainset and the predict() method

# %%
from surprise import KNNBasic
from surprise import Dataset

# Load the movielens-100k dataset
data = Dataset.load_builtin('ml-100k')

# %%
# Retrieve the trainset
trainset = data.build_full_trainset()

# %%
# Build an algorithm, and train it
algo = KNNBasic()
algo.fit(trainset)
# Out:
# Computing the msd similarity matrix...
# Done computing similarity matrix.

# %%
# We can now predict ratings by directly calling the predict() method. 
# Let’s say you’re interested in user 196 and item 302 (make sure they’re in the trainset!), 
# and you know that the true rating rui=4:
uid = str(196) # raw user id (as in the ratings file). They are **strings**! 
iid = str(302) # raw item id (as in the ratings file). They are **strings**!

# get a prediction for specific users and items.
pred = algo.predict(uid,iid,r_ui=4,verbose=True)
# Out:
# user: 196        item: 302        r_ui = 4.00   est = 4.06   {'actual_k': 40, 'was_impossible': False}

# %% [markdown]
# 2. Use a custom dataset

# %% [markdown]
#     Surprise has a set of builtin datasets, but you can of course use a custom dataset. Loading a rating dataset can be done either from a file (e.g. a csv file), or from a pandas dataframe. Either way, you will need to define a Reader object for Surprise to be able to parse the file or the dataframe.

# %% [markdown]
#     2.1 从csv文件加载评分数据集

# %%
# To load a dataset from a file (e.g. a csv file), you will need the load_from_file() method:
import os
from surprise import BaselineOnly
from surprise import Dataset
from surprise import Reader
from surprise.model_selection import cross_validate

# path to dataset file
file_path = os.path.expanduser("C:\\Users\\Dean\\.surprise_data\\ml-100k\\ml-100k\\u.data")

# As we're loading a custom dataset, we need to define a reader. In the
# movielens-100k dataset, each line has the following format:
# 'user item rating timestamp', separated by '\t' characters.
reader = Reader(line_format='user item rating timestamp',sep='\t')

data = Dataset.load_from_file(file_path,reader=reader)

# %%
# We can now use this dataset as we please, e.g. calling cross_validate
cross_validate(BaselineOnly(),data,verbose=True)
# Out:
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Estimating biases using als...
# Evaluating RMSE, MAE of algorithm BaselineOnly on 5 split(s).
#
#                   Fold 1  Fold 2  Fold 3  Fold 4  Fold 5  Mean    Std
# RMSE (testset)    0.9407  0.9433  0.9383  0.9439  0.9525  0.9437  0.0048
# MAE (testset)     0.7443  0.7468  0.7437  0.7515  0.7552  0.7483  0.0044
# Fit time          0.17    0.19    0.19    0.18    0.19    0.19    0.01
# Test time         0.08    0.10    0.12    0.12    0.12    0.11    0.01
# {'test_rmse': array([0.94070162, 0.94325116, 0.93827524, 0.94393216, 0.9524632 ]),
#  'test_mae': array([0.74434879, 0.74678171, 0.74374399, 0.7515291 , 0.75522879]),
#  'fit_time': (0.17253971099853516,
#   0.19447922706604004,
#   0.18949365615844727,
#   0.18453431129455566,
#   0.1874995231628418),
#  'test_time': (0.08376169204711914,
#   0.0967409610748291,
#   0.11668705940246582,
#   0.11668705940246582,
#   0.11768412590026855)}

# %% [markdown]
#     2.1 从pandas Dataframe加载评分数据集

# %%
# To load a dataset from a pandas dataframe, you will need the load_from_df() method. You will also need a Reader object,
# but only the rating_scale parameter must be specified. The dataframe must have three columns, 
# corresponding to the user (raw) ids, the item (raw) ids, and the ratings in this order. 
# Each row thus corresponds to a given rating. This is not restrictive as you can reorder the columns of your dataframe easily.
import pandas as pd

from surprise import NormalPredictor
from surprise import Dataset
from surprise import Reader
from surprise.model_selection import cross_validate

# Creation of the dataframe.Column names are irrelevant.
ratings_dict = {'itemID':[1,1,1,2,2],
               'userID':[9,32,2,45,'user_foo'],
               'rating':[3,2,4,3,1]}
df = pd.DataFrame(ratings_dict)

# %%
df
# Out:
#    itemID    userID  rating
# 0       1         9       3
# 1       1        32       2
# 2       1         2       4
# 3       2        45       3
# 4       2  user_foo       1

# %%
# A reader is still needed but only the rating_scale param is requiered.
reader = Reader(rating_scale=(1,5))

# %%
# The columns must correspond to user id,item id and ratings (in that order).
data = Dataset.load_from_df(df[['userID','itemID','rating']],reader)

# %%
# We can now use this dataset as we please,e.g. calling cross_validate
cross_validate(NormalPredictor(),data,cv=2)
# Out:
# {'test_rmse': array([1.57547085, 1.59500372]),
#  'test_mae': array([1.40726814, 1.50640634]),
#  'fit_time': (0.0, 0.0),
#  'test_time': (0.0, 0.0)}

# %% [markdown]
# 3. Use cross-validation

# %% [markdown]
#     3.1 Use cross-validation iterators

# %%
# For cross-validation, we can use the cross_validate() function that does all the hard work for us. 
# But for a better control, we can also instanciate a cross-validation iterator, 
# and make predictions over each split using the split() method of the iterator, and the test() method of the algorithm. 
# Here is an example where we use a classical K-fold cross-validation procedure with 3 splits:
from surprise import SVD
from surprise import Dataset
from surprise import accuracy
from surprise.model_selection import KFold

# Load the movielens-100k dataset
data = Dataset.load_builtin('ml-100k')

# define a cross-validation iterator
kf = KFold(n_splits=3)

algo = SVD()

# %%
for trainset,testset in kf.split(data):
    # train and test algorithm.
    algo.fit(trainset)
    predictions = algo.test(testset)
    
    # compute and print Root Mean Squared Error
    accuracy.rmse(predictions,verbose=True)
# Out:
# RMSE: 0.9424
# RMSE: 0.9470
# RMSE: 0.9468

# %% [markdown]
#     3.2 Use 预先定义好的 cross-validation iterators

# %%
# A special case of cross-validation is when the folds are already predefined by some files. 
# For instance, the movielens-100K dataset already provides 5 train and test files (u1.base, u1.test … u5.base, u5.test).
# Surprise can handle this case by using a surprise.model_selection.split.PredefinedKFold object:
from surprise import SVD
from surprise import Dataset
from surprise import Reader
from surprise import accuracy
from surprise.model_selection import PredefinedKFold

# path to dataset folder
files_dir = os.path.expanduser('C:\\Users\\Dean\\.surprise_data\\ml-100k\\ml-100k\\')
                               
# This time,we'll use the built-in reader.
reader = Reader('ml-100k')

# folds_files is a list of tuples containing file paths:
# [(u1.base, u1.test), (u2.base, u2.test), ... (u5.base, u5.test)]
train_file = files_dir + 'u%d.base'
test_file = files_dir + 'u%d.test'
folds_files = [(train_file % i,test_file % i) for i in (1,2,3,4,5)]

data = Dataset.load_from_folds(folds_files,reader=reader)
pkf = PredefinedKFold()

# %%
algo = SVD()

# %%
for trainset,testset in pkf.split(data):
    # train and test algorithm
    algo.fit(trainset)
    predictions = algo.test(testset)
    
    # compute and print RootMean Squared Error
    accuracy.rmse(predictions,verbose=True)
# Out:
# RMSE: 0.9519
# RMSE: 0.9401
# RMSE: 0.9312
# RMSE: 0.9320
# RMSE: 0.9319

# %% [markdown]
#     Of course, nothing prevents you from only loading a single file for training and a single file for testing. However, the folds_files parameter still needs to be a list.

# %% [markdown]
# 4. Tune(调整) algorithm parameters with GridSearchCV

# %% [markdown]
#     The cross_validate() function reports accuracy metric over a cross-validation procedure for a given set of parameters. If you want to know which parameter combination yields the best results, the GridSearchCV class comes to the rescue. Given a dict of parameters, this class exhaustively tries all the combinations of parameters and reports the best parameters for any accuracy measure (averaged over the different splits).

# %%
# Here is an example where we try different values for parameters n_epochs, lr_all and reg_all of the SVD algorithm.
from surprise import SVD
from surprise import Dataset
from surprise.model_selection import GridSearchCV

# Use movielens-100k
data = Dataset.load_builtin('ml-100k')

param_grid = {'n_epochs':[5,10],'lr_all':[0.002,0.005],'reg_all':[0.4,0.6]}
gs = GridSearchCV(SVD,param_grid,measures=['rmse','mae'],cv=3)

# %%
gs.fit(data)

# %%
# beat RMSE score
print(gs.best_score['rmse'])
# Out:
# 0.9641831047333728

# %%
# combination of parameters that gave the best RMSE score
print(gs.best_params['rmse'])
# Out:
# {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.4}

# %% [markdown]
#     We are here evaluating the average RMSE and MAE over a 3-fold cross-validation procedure, but any cross-validation iterator can used.
#
#     Once fit() has been called, the best_estimator attribute gives us an algorithm instance with the optimal set of parameters, which can be used how we please:

# %%
# We can now use the algorithm that yields the best rmse:
algo = gs.best_estimator['rmse']
algo.fit(data.build_full_trainset())

# %% [markdown]
# Note
#
#     Dictionary parameters such as bsl_options and sim_options require particular treatment. See usage example below:

# %%
param_grid = {'k':[10,20],
             'sim_options':{'name':['msd','cosine'],
                           'min_suport':[1,5],
                           'user_based':[False]}
             }

# %%
# Naturally, both can be combined, for example for the KNNBaseline algorithm:
param_grid = {'bsl_options':{'method':['als','sgd'],
                            'reg':[1,2]},
             'k':[2,3],
             'sim_options':{'name':['msd','cosine'],
                           'min_support':[1,5],
                           'user_based':[False
                                        ]}
             }

# %%
# For further analysis, the cv_results attribute has all the needed information and can be imported in a pandas dataframe:
results_df = pd.DataFrame.from_dict(gs.cv_results)

# %%
gs.cv_results
# Out:
# {'split0_test_rmse': array([0.99753609, 1.00404734, 0.97432612, 0.983051  , 0.97874205,
#         0.98657131, 0.96444155, 0.97410058]),
#  'split1_test_rmse': array([0.99205488, 0.99828238, 0.96949079, 0.97820284, 0.9734913 ,
#         0.98169526, 0.96005226, 0.96966746]),
#  'split2_test_rmse': array([1.00162802, 1.00789653, 0.97798728, 0.98689593, 0.98221953,
#         0.99040454, 0.9680555 , 0.97818143]),
#  'mean_test_rmse': array([0.997073  , 1.00340875, 0.97393473, 0.98271659, 0.97815096,
#         0.9862237 , 0.9641831 , 0.97398316]),
#  'std_test_rmse': array([0.00392191, 0.00395085, 0.0034797 , 0.00355681, 0.00358771,
#         0.00356404, 0.00327242, 0.00347681]),
#  'rank_test_rmse': array([7, 8, 2, 5, 4, 6, 1, 3], dtype=int64),
#  'split0_test_mae': array([0.80650722, 0.81557525, 0.78270655, 0.79352316, 0.78689419,
#         0.797029  , 0.77334321, 0.78494728]),
#  'split1_test_mae': array([0.80076225, 0.80943114, 0.77767916, 0.78853261, 0.78170445,
#         0.7919644 , 0.76909475, 0.78054282]),
#  'split2_test_mae': array([0.80981992, 0.81881258, 0.78498049, 0.79624274, 0.78926803,
#         0.79989127, 0.77516144, 0.78748534]),
#  'mean_test_mae': array([0.80569647, 0.81460632, 0.78178873, 0.79276617, 0.78595556,
#         0.79629489, 0.77253313, 0.78432515]),
#  'std_test_mae': array([0.00374195, 0.00389075, 0.00305059, 0.00319283, 0.00315834,
#         0.0032775 , 0.00254209, 0.00286821]),
#  'rank_test_mae': array([7, 8, 2, 5, 4, 6, 1, 3], dtype=int64),
#  'mean_fit_time': array([0.94447446, 0.9228847 , 0.931518  , 0.92155528, 1.86835559,
#         1.85071715, 1.85568396, 1.86069624]),
#  'std_fit_time': array([0.00295158, 0.00330347, 0.00356247, 0.00140235, 0.02680183,
#         0.003853  , 0.00863023, 0.012976  ]),
#  'mean_test_time': array([0.22903601, 0.22537708, 0.24302562, 0.22704927, 0.22173468,
#         0.22140686, 0.22506468, 0.22338343]),
#  'std_test_time': array([0.02518942, 0.02328332, 0.00234435, 0.02252653, 0.02280087,
#         0.02330316, 0.02095642, 0.02403783]),
#  'params': [{'n_epochs': 5, 'lr_all': 0.002, 'reg_all': 0.4},
#   {'n_epochs': 5, 'lr_all': 0.002, 'reg_all': 0.6},
#   {'n_epochs': 5, 'lr_all': 0.005, 'reg_all': 0.4},
#   {'n_epochs': 5, 'lr_all': 0.005, 'reg_all': 0.6},
#   {'n_epochs': 10, 'lr_all': 0.002, 'reg_all': 0.4},
#   {'n_epochs': 10, 'lr_all': 0.002, 'reg_all': 0.6},
#   {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.4},
#   {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.6}],
#  'param_n_epochs': [5, 5, 5, 5, 10, 10, 10, 10],
#  'param_lr_all': [0.002, 0.002, 0.005, 0.005, 0.002, 0.002, 0.005, 0.005],
#  'param_reg_all': [0.4, 0.6, 0.4, 0.6, 0.4, 0.6, 0.4, 0.6]}

# %%
# As you can see, each list has the same size of the number of parameter combination. It corresponds to the following table:
results_df
# Out:
#    split0_test_rmse  split1_test_rmse  split2_test_rmse  mean_test_rmse  \
# 0          0.997536          0.992055          1.001628        0.997073
# 1          1.004047          0.998282          1.007897        1.003409
# 2          0.974326          0.969491          0.977987        0.973935
# 3          0.983051          0.978203          0.986896        0.982717
# 4          0.978742          0.973491          0.982220        0.978151
# 5          0.986571          0.981695          0.990405        0.986224
# 6          0.964442          0.960052          0.968056        0.964183
# 7          0.974101          0.969667          0.978181        0.973983
#
#    std_test_rmse  rank_test_rmse  split0_test_mae  split1_test_mae  \
# 0       0.003922               7         0.806507         0.800762
# 1       0.003951               8         0.815575         0.809431
# 2       0.003480               2         0.782707         0.777679
# 3       0.003557               5         0.793523         0.788533
# 4       0.003588               4         0.786894         0.781704
# 5       0.003564               6         0.797029         0.791964
# 6       0.003272               1         0.773343         0.769095
# 7       0.003477               3         0.784947         0.780543
#
#    split2_test_mae  mean_test_mae  std_test_mae  rank_test_mae  mean_fit_time  \
# 0         0.809820       0.805696      0.003742              7       0.944474
# 1         0.818813       0.814606      0.003891              8       0.922885
# 2         0.784980       0.781789      0.003051              2       0.931518
# 3         0.796243       0.792766      0.003193              5       0.921555
# 4         0.789268       0.785956      0.003158              4       1.868356
# 5         0.799891       0.796295      0.003277              6       1.850717
# 6         0.775161       0.772533      0.002542              1       1.855684
# 7         0.787485       0.784325      0.002868              3       1.860696
#
#    std_fit_time  mean_test_time  std_test_time  \
# 0      0.002952        0.229036       0.025189
# 1      0.003303        0.225377       0.023283
# 2      0.003562        0.243026       0.002344
# 3      0.001402        0.227049       0.022527
# 4      0.026802        0.221735       0.022801
# 5      0.003853        0.221407       0.023303
# 6      0.008630        0.225065       0.020956
# 7      0.012976        0.223383       0.024038
#
#                                               params  param_n_epochs  \
# 0   {'n_epochs': 5, 'lr_all': 0.002, 'reg_all': 0.4}               5
# 1   {'n_epochs': 5, 'lr_all': 0.002, 'reg_all': 0.6}               5
# 2   {'n_epochs': 5, 'lr_all': 0.005, 'reg_all': 0.4}               5
# 3   {'n_epochs': 5, 'lr_all': 0.005, 'reg_all': 0.6}               5
# 4  {'n_epochs': 10, 'lr_all': 0.002, 'reg_all': 0.4}              10
# 5  {'n_epochs': 10, 'lr_all': 0.002, 'reg_all': 0.6}              10
# 6  {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.4}              10
# 7  {'n_epochs': 10, 'lr_all': 0.005, 'reg_all': 0.6}              10
#
#    param_lr_all  param_reg_all
# 0         0.002            0.4
# 1         0.002            0.6
# 2         0.005            0.4
# 3         0.005            0.6
# 4         0.002            0.4
# 5         0.002            0.6
# 6         0.005            0.4
# 7         0.005            0.6

# %% [markdown]
# 5. Command line usage

# %% [markdown]
# Surprise can also be used from the command line, for example:
#
#     surprise -algo SVD -params "{'n_epochs': 5, 'verbose': True}" -load-builtin ml-100k -n-folds 3

# %% [markdown]
# See detailed usage by running:
#
#     surprise -h
